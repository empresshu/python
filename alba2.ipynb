# %%
import numpy as np
import pandas as pd
import sys

# %%
data_frame = pd.read_csv("c:/20180430_data_kpop_new.csv", engine='python') # dataframe

# %%
input_file = sys.argv[1]

output_file = sys.argv[2]

# %%
data_frame.head()
# Out:
#         Vertex  공식채널  media  UGC  cover  reaction  fancam  flashmob  playlist  \
# 0  lH_lsVWEM6I   NaN    NaN  NaN    NaN       NaN     NaN       NaN       NaN
# 1  oNEFXcWRIG8   NaN    NaN  NaN    NaN       NaN     NaN       NaN       NaN
# 2  1EB2OWWtazk   NaN    NaN  NaN    NaN       NaN     NaN       NaN       NaN
# 3  aV2ImPCRwcA   NaN    NaN  NaN    NaN       NaN     NaN       NaN       NaN
# 4  LwyY-PwNzCs   NaN    NaN  NaN    NaN       NaN     NaN       NaN       NaN
#
#    chart     ...       Dislikes Count  Custom Menu Item Text  \
# 0    NaN     ...                 30.0  Play Video in Browser
# 1    NaN     ...                  6.0  Play Video in Browser
# 2    NaN     ...                 31.0  Play Video in Browser
# 3    NaN     ...                120.0  Play Video in Browser
# 4    NaN     ...                199.0  Play Video in Browser
#
#                        Custom Menu Item Action  Unnamed: 51  Unnamed: 52  \
# ...
